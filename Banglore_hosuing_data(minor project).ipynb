# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from ipywidgets import Dropdown, FloatSlider, IntSlider, interact
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv("/content/Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.isnull().sum()
#as we can see, society, balcony have many null values, so to maintain highest accuracy we will remove these
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df = df.drop(columns=['availability','balcony']) # we are removing availabilty as it is not going to be a factor in changing price

# %%
df = df.drop(columns=['society'])

# %%
df['area_type'].value_counts()
#since this data is heavily biased towards super built-up Area, we will drop the column
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
df = df.drop(columns=['area_type'])

# %%
df.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df1 = df
#creating out a copy of df incase of a function malfuncction

# %%
df1.dropna(inplace=True)
#clearing out the rows containing NaN values

# %%
df1.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
df1
#here in size column we can see many same inputs and since the format is in object we will first make it into integer format
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13246 rows x 5 columns]

# %%
df1['bedrooms'] = df1['size'].apply(lambda x: int(x.split(" ")[0]))
df1.head()
#here we have created a new column "bedrooms" in which we separated integers from size column
# Out:
#                    location       size total_sqft  bath   price  bedrooms
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07         2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00         4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00         3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00         3
# 4                  Kothanur      2 BHK       1200   2.0   51.00         2

# %%
#now we will check for unique values of bedrooms and remove size column
df1 = df1.drop(columns=['size'])

# %%
df1['bedrooms'].unique()
# here we can see that 27 and 43 rooms are errors hence we will limit our data to 20 rooms only
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18])

# %%
df1=df1[df1['bedrooms']<20]

# %%
df1['bedrooms'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 10, 19, 16, 14, 12, 13, 18])

# %%
import numpy as np
def convert_num(x):
  tokens = x.split('-')
  if len(tokens)==2:
    return(np.float64(tokens[0])+np.float64(tokens[1]))/2
  try:
    return np.float64(x)
  except:
    return None
  # this is a function created to get only one value that is mean of extremes of range in total_sqft column.

# %%
df1.total_sqft =df1.total_sqft.apply(convert_num)

# %%
df1.isnull().sum()
#here we can see some nan values have been generated and hence we will remove them
# Out:
# location       0
# total_sqft    46
# bath           0
# price          0
# bedrooms       0
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# location      0
# total_sqft    0
# bath          0
# price         0
# bedrooms      0
# dtype: int64

# %%
df1.info()
#here we can see that we have created all other obects into float of int type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13198 entries, 0 to 13319
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   location    13198 non-null  object
#  1   total_sqft  13198 non-null  float64
#  2   bath        13198 non-null  float64
#  3   price       13198 non-null  float64
#  4   bedrooms    13198 non-null  int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 618.7+ KB

# %%
df1['total_sqft'].describe()
# Out:
# count    13198.000000
# mean      1554.750472
# std       1236.122856
# min          1.000000
# 25%       1100.000000
# 50%       1275.000000
# 75%       1671.500000
# max      52272.000000
# Name: total_sqft, dtype: float64

# %%
plt.boxplot(df1["total_sqft"])
#here a lot of outrider values are there, hence we will fix it.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c6c8ceff0a0>,
#   <matplotlib.lines.Line2D at 0x7c6c8ceff340>],
#  'caps': [<matplotlib.lines.Line2D at 0x7c6c8ceff5e0>,
#   <matplotlib.lines.Line2D at 0x7c6c8ceff880>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7c6c8cefee00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c6c8ceffb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c6c8ceffdc0>],
#  'means': []}

# %%
low,high = df1['total_sqft'].quantile([0.1,0.9])
mask_area = df1['total_sqft'].between(low,high)
df1 = df1[mask_area]
plt.boxplot(df1['total_sqft'])
#now we can see that we have prepared a better boxplot, here lower line of box represents 25%, yellow line represents 50%,top line represents 75% data lying under that value.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c6c8ae0ef20>,
#   <matplotlib.lines.Line2D at 0x7c6c8ae0f1c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7c6c8ae0f460>,
#   <matplotlib.lines.Line2D at 0x7c6c8ae0f700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7c6c8ae0ec80>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c6c8ae0f9a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c6c8ae0fc40>],
#  'means': []}

# %%
df1['bath'].value_counts()
#here we can see that not much variation is seen after 10,, hence we will remove it
# Out:
# 2.0     6468
# 3.0     2933
# 4.0      632
# 5.0      190
# 1.0      135
# 6.0      117
# 7.0       46
# 8.0       31
# 9.0       22
# 10.0       9
# 11.0       3
# 12.0       3
# 16.0       1
# 15.0       1
# 13.0       1
# 18.0       1
# Name: bath, dtype: int64

# %%
df1=df1[df1['bath']<=10]

# %%
df1['bath'].value_counts()
# Out:
# 2.0     6468
# 3.0     2933
# 4.0      632
# 5.0      190
# 1.0      135
# 6.0      117
# 7.0       46
# 8.0       31
# 9.0       22
# 10.0       9
# Name: bath, dtype: int64

# %%
location_stats=df1

# %%
df1.location.nunique()
# Out:
# 1121

# %%
#DOUBT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
df1.location=df1.location.apply(lambda x:x.strip())
location_stats=df1['location'].value_counts(ascending=False)
location_stats
#here we can see that many place have only one or two
# Out:
# Whitefield               412
# Sarjapur  Road           320
# Electronic City          242
# Kanakpura Road           218
# Thanisandra              205
#                         ...
# Maruthi Extension          1
# Okalipura                  1
# Vasantapura main road      1
# Bapuji Layout              1
# Annaiah Reddy Layout       1
# Name: location, Length: 1118, dtype: int64

# %%
location_stats_less_than_10=location_stats[location_stats<=10]
len(location_stats_less_than_10)
# Out:
# 921

# %%
df1.location=df1.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
len(df1.location.unique())
# Out:
# 198

# %%
df1['price_per_sqft']=df1['price']*100000/df1['total_sqft']

# %%
df1['price_per_sqft'].describe()
# Out:
# count    10583.000000
# mean      6241.745188
# std       3694.372194
# min        500.000000
# 25%       4206.495405
# 50%       5252.246026
# 75%       6760.563380
# max      53150.000000
# Name: price_per_sqft, dtype: float64

# %%
plt.boxplot(df1['price_per_sqft'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c6c8ac91ea0>,
#   <matplotlib.lines.Line2D at 0x7c6c8ac92140>],
#  'caps': [<matplotlib.lines.Line2D at 0x7c6c8ac91ff0>,
#   <matplotlib.lines.Line2D at 0x7c6c8ac923b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7c6c8ac91c00>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c6c8ac92650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c6c8ac928f0>],
#  'means': []}

# %%
low, high =df1["price_per_sqft"].quantile([0.1,0.9])
mask_area=df1["price_per_sqft"].between(low,high)
df1=df1[mask_area]

# %%
plt.boxplot(df1['price_per_sqft'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c6c8ad10700>,
#   <matplotlib.lines.Line2D at 0x7c6c8ad109a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7c6c8ad10c40>,
#   <matplotlib.lines.Line2D at 0x7c6c8ad10ee0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7c6c8ad104c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c6c8ad11180>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c6c8ad11420>],
#  'means': []}

# %%
df1.describe()
# Out:
#         total_sqft         bath        price     bedrooms  price_per_sqft
# count  8465.000000  8465.000000  8465.000000  8465.000000     8465.000000
# mean   1381.476215     2.425635    77.729213     2.564442     5524.512900
# std     324.504940     0.723413    31.925031     0.731991     1397.931569
# min     900.000000     1.000000    32.000000     1.000000     3500.408831
# 25%    1150.000000     2.000000    54.790000     2.000000     4422.310757
# 50%    1293.000000     2.000000    69.230000     2.000000     5252.246026
# 75%    1575.000000     3.000000    93.865000     3.000000     6363.636364
# max    2400.000000    10.000000   235.000000    10.000000     9893.048128

# %%
df1.head(10)
#DOUBT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Out:
#                     location  total_sqft  bath   price  bedrooms  \
# 0   Electronic City Phase II      1056.0   2.0   39.07         2
# 2                Uttarahalli      1440.0   2.0   62.00         3
# 3         Lingadheeranahalli      1521.0   3.0   95.00         3
# 4                   Kothanur      1200.0   2.0   51.00         2
# 8               Marathahalli      1310.0   3.0   63.25         3
# 10                Whitefield      1800.0   2.0   70.00         3
# 12        7th Phase JP Nagar      1000.0   2.0   38.00         2
# 13                 Gottigere      1100.0   2.0   40.00         2
# 14                  Sarjapur      2250.0   3.0  148.00         3
# 15               Mysore Road      1175.0   2.0   73.50         2
#
#     price_per_sqft
# 0      3699.810606
# 2      4305.555556
# 3      6245.890861
# 4      4250.000000
# 8      4828.244275
# 10     3888.888889
# 12     3800.000000
# 13     3636.363636
# 14     6577.777778
# 15     6255.319149

# %%
df1.drop(columns=['price_per_sqft'])
# Out:
#                        location  total_sqft  bath   price  bedrooms
# 0      Electronic City Phase II      1056.0   2.0   39.07         2
# 2                   Uttarahalli      1440.0   2.0   62.00         3
# 3            Lingadheeranahalli      1521.0   3.0   95.00         3
# 4                      Kothanur      1200.0   2.0   51.00         2
# 8                  Marathahalli      1310.0   3.0   63.25         3
# ...                         ...         ...   ...     ...       ...
# 13310              Rachenahalli      1050.0   2.0   52.71         2
# 13312                 Bellandur      1262.0   2.0   47.00         2
# 13313               Uttarahalli      1345.0   2.0   57.00         3
# 13314         Green Glen Layout      1715.0   3.0  112.00         3
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00         2
#
# [8465 rows x 5 columns]

# %%
X=df1[["location","total_sqft","bath","bedrooms"]]
y=df1.price
model1=make_pipeline(
    OneHotEncoder(),
    LinearRegression())
model1.fit(X,y)
# Out:
# Pipeline(steps=[('onehotencoder', OneHotEncoder()),
#                 ('linearregression', LinearRegression())])

# %%
y_mean=y.mean()
Y_pred_baseline=[y_mean]*len(y)

# %%
mae_baseline=mean_absolute_error(y,Y_pred_baseline)
mae_baseline
# Out:
# 24.84767555672937

# %%
y_m=model1.predict(X)
y_m
# Out:
# array([ 57.42632612,  59.72393895,  91.0620633 , ...,  59.48506553,
#        111.32505228,  44.03252945])

# %%
mae_model=mean_absolute_error(y,y_m)
mae_model
# Out:
# 10.427091234351213

# %%
def make_prediction(location,total_sqft, bath, bedrooms):
    data={
        "location": location,
        "total_sqft": total_sqft,
        "bath": bath,
        "bedrooms": bedrooms

    }
    df = pd.DataFrame(data, index=[0])

    prediction = model1.predict(df)
    return f"Predicted apartment price: {prediction}"

# %%
interact(
    make_prediction,
    location=Dropdown(options=sorted(X_train["location"].unique())),

    total_sqft=IntSlider(
        min=X_train["total_sqft"].min(),
        max=X_train["total_sqft"].max(),
        value=X_train["total_sqft"].mean(),
    ),


    bath=IntSlider(
    min=X_train["bath"].min(),
    max=X_train["bath"].max(),
    value=X_train["bath"].mean(),
    ),

    bedrooms=IntSlider(
    min=X_train["bedrooms"].min(),
    max=X_train["bedrooms"].max(),
    value=X_train["bedrooms"].mean(),
    ),
);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-d3f50c2189c0> in <cell line: 1>()
#       1 interact(
#       2     make_prediction,
# ----> 3     location=Dropdown(options=sorted(X_train["location"].unique())),
#       4
#       5     total_sqft=IntSlider(
#
# NameError: name 'X_train' is not defined
